# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !pip install webvtt-py

# %%
import webvtt

# %%
vtt = webvtt.read('/content/drive/My Drive/project/기타 자료/WCG 2019 New Horizons _ AI Masters Group Stage _ AI_Soccer_K vs CHINA_UNION-NWBtvymECOI.en.vtt')

# %%
vtt[0].text
# Out:
# ' \nalright guys welcome to the CC u 2019'

# %%
vtt[2].text.splitlines()
# Out:
# ['alright guys welcome to the CC u 2019',
#  'may I masters and my name is Jacob my']

# %%
lines = []
for line in vtt:
    lines.extend(line.text.strip().splitlines())

# %%
for i in range(10):
    print(lines[i])
# Out:
# alright guys welcome to the CC u 2019
# alright guys welcome to the CC u 2019
# alright guys welcome to the CC u 2019
# may I masters and my name is Jacob my
# may I masters and my name is Jacob my
# may I masters and my name is Jacob my
# name is sinners my name is Philip Oh
# name is sinners my name is Philip Oh
# name is sinners my name is Philip Oh
# finally they am master today is the

# %%
transcript = ""
previous = None
for line in lines:
    if line == previous:
       continue
    transcript += " " + line
    previous = line

# %%
transcript
# Out:
# " alright guys welcome to the CC u 2019 may I masters and my name is Jacob my name is sinners my name is Philip Oh finally they am master today is the finer right now so Simone would you feel like that is our WCG 2019 the very first time here in China Xian you know I'm really looking forward to what is going to happen today you Philip meet you I'm really excited and the players had like two additional weeks to improve their algorithms and they need to perform today in the main stage yeah we have to introduce Philip once again here because actually Philip is one of the developers of this game of our AI masters so Philip here is our true master here yeah true Massa and by the way welcome to see a welcome to China welcome yeah it's a pleasure to be here my first time in Chien and the city is amazing yeah really beautiful Tomas we're here in the WCG is there pressure for us to partner with yous and this here's the question I think a lot of people we would just wonder what is the AMS er a
# ...
