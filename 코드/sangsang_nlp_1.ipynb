# %%
import pandas as pd
import numpy as np


df = pd.read_csv("C:\\Users\\Affinity\\Google 드라이브\\project\\football-events\\events.csv")
df.head()
# Out:
#      id_odsp   id_event  sort_order  time  \
# 0  UFot0hit/  UFot0hit1           1     2
# 1  UFot0hit/  UFot0hit2           2     4
# 2  UFot0hit/  UFot0hit3           3     4
# 3  UFot0hit/  UFot0hit4           4     7
# 4  UFot0hit/  UFot0hit5           5     7
#
#                                                 text  event_type  event_type2  \
# 0  Attempt missed. Mladen Petric (Hamburg) left f...           1         12.0
# 1  Corner,  Borussia Dortmund. Conceded by Dennis...           2          NaN
# 2  Corner,  Borussia Dortmund. Conceded by Heiko ...           2          NaN
# 3           Foul by Sven Bender (Borussia Dortmund).           3          NaN
# 4  Gokhan Tore (Hamburg) wins a free kick in the ...           8          NaN
#
#    side         event_team           opponent  ... player_in player_out  \
# 0     2         Hamburg SV  Borussia Dortmund  ...       NaN        NaN
# 1     1  Borussia Dortmund         Hamburg SV  ...       NaN        NaN
# 2     1  Borussia Dortmund         Hamburg SV  ...       NaN        NaN
# 3     1  Borussia Dortmund         Hamburg SV  ...       NaN        NaN
# 4     2         Hamburg SV  Borussia Dortmund  ...       NaN        NaN
#
#   shot_place shot_outcome  is_goal  location  bodypart  assist_method  \
# 0        6.0          2.0        0       9.0       2.0              1
# 1        NaN          NaN        0       NaN       NaN              0
# 2        NaN          NaN        0       NaN       NaN              0
# 3        NaN          NaN        0       NaN       NaN              0
# 4        NaN          NaN        0       2.0       NaN              0
#
#    situation  fast_break
# 0        1.0           0
# 1        NaN           0
# 2        NaN           0
# 3        NaN           0
# 4        NaN           0
#
# [5 rows x 22 columns]

# %%
df.text
# Out:
# 0         Attempt missed. Mladen Petric (Hamburg) left f...
# 1         Corner,  Borussia Dortmund. Conceded by Dennis...
# 2         Corner,  Borussia Dortmund. Conceded by Heiko ...
# 3                  Foul by Sven Bender (Borussia Dortmund).
# 4         Gokhan Tore (Hamburg) wins a free kick in the ...
# 5               Hand ball by Jose Paolo Guerrero (Hamburg).
# 6            Corner,  Hamburg. Conceded by Lukasz Piszczek.
# 7         Chris Lowe (Borussia Dortmund) wins a free kic...
# 8                            Foul by Gojko Kacar (Hamburg).
# 9                            Foul by Gokhan Tore (Hamburg).
# 10        Sven Bender (Borussia Dortmund) wins a free ki...
# 11        Attempt missed. Shinji Kagawa (Borussia Dortmu...
# 12                           Foul by Gojko Kacar (Hamburg).
# 13        Goal!  Borussia Dortmund 1, Hamburg 0. Kevin G...
# 14        Attempt blocked. Mats Hummels (Borussia Dortmu...
# 15                 Foul by Sven Bender (Borussia Dortmund).
# 16        Mladen Petric (Hamburg) wins a free kick in th...
# 17        Attempt blocked. Tomas Rincon (Hamburg) right ...
# 18        Shinji Kagawa (Borussia Dortmund) hits the rig...
# 19        Corner,  Borussia Dortmund. Conceded by Dennis...
# 20        Attempt blocked. Ilkay Gundogan (Borussia Dort...
# 21        Corner,  Borussia Dortmund. Conceded by Heiko ...
# 22        Attempt saved. Mats Hummels (Borussia Dortmund...
# 23        Lukasz Piszczek (Borussia Dortmund) wins a fre...
# 24                           Foul by Gokhan Tore (Hamburg).
# 25        Attempt missed. Shinji Kagawa (Borussia Dortmu...
# 26        Goal!  Borussia Dortmund 2, Hamburg 0. Mario G...
# 27           Foul by Kevin Grosskreutz (Borussia Dortmund).
# 28        Gokhan Tore (Hamburg) wins a free kick on the ...
# 29        Roman Weidenfeller (Borussia Dortmund) wins a ...
#                                 ...
# 940979    Attempt blocked. Ervin Zukanovic (Atalanta) he...
# 940980    Alessandro Bastoni (Atalanta) wins a free kick...
# 940981                     Foul by Luis Muriel (Sampdoria).
# 940982      Corner,  Atalanta. Conceded by Daniel Pavlovic.
# 940983    Attempt blocked. Remo Freuler (Atalanta) right...
# 940984    Offside, Atalanta. Remo Freuler tries a throug...
# 940985    Ervin Zukanovic (Atalanta) wins a free kick in...
# 940986                  Foul by Filip Djuricic (Sampdoria).
# 940987    Filip Djuricic (Sampdoria) is shown the yellow...
# 940988    Substitution, Sampdoria. Ante Budimir replaces...
# 940989                  Foul by Ervin Zukanovic (Atalanta).
# 940990    Patrik Schick (Sampdoria) wins a free kick on ...
# 940991    Attempt missed. Alberto Grassi (Atalanta) righ...
# 940992    Attempt saved. Alejandro Gomez (Atalanta) righ...
# 940993    Attempt saved. Fabio Quagliarella (Sampdoria) ...
# 940994    Alejandro Gomez (Atalanta) wins a free kick in...
# 940995                    Foul by Ante Budimir (Sampdoria).
# 940996    Substitution, Atalanta. Rafael Toloi replaces ...
# 940997    Andrea Petagna (Atalanta) wins a free kick in ...
# 940998                  Foul by Milan Skriniar (Sampdoria).
# 940999    Milan Skriniar (Sampdoria) is shown the yellow...
# 941000      Corner,  Atalanta. Conceded by Daniel Pavlovic.
# 941001    Alessandro Bastoni (Atalanta) wins a free kick...
# 941002                    Foul by Ante Budimir (Sampdoria).
# 941003              Foul by Leonardo Spinazzola (Atalanta).
# 941004    Lucas Torreira (Sampdoria) wins a free kick in...
# 941005     Corner,  Sampdoria. Conceded by Andrea Masiello.
# 941006    Attempt missed. Fabio Quagliarella (Sampdoria)...
# 941007    Alberto Grassi (Atalanta) wins a free kick on ...
# 941008                   Foul by Pedro Pereira (Sampdoria).
# Name: text, Length: 941009, dtype: object

# %%
import nltk
from nltk.tokenize import sent_tokenize


nltk.download("punkt")
text = sent_tokenize(df.text[0])
text
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Affinity\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# ['Attempt missed.',
#  'Mladen Petric (Hamburg) left footed shot from the left side of the box is high and wide to the left.',
#  'Assisted by Gokhan Tore.']

# %%
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from collections import Counter
nltk.download('stopwords')


vocab = Counter()

sentences = []
stop_words = set(stopwords.words("english"))

for i in text:
    sentence = word_tokenize(i)
    result = []

    for word in sentence:
        word = word.lower()
        if word not in stop_words:
            if len(word) > 2:
                result.append(word)
                vocab[word] = vocab[word] + 1
    sentences.append(result)

print(sentences)
# Out:
# [['attempt', 'missed'], ['mladen', 'petric', 'hamburg', 'left', 'footed', 'shot', 'left', 'side', 'box', 'high', 'wide', 'left'], ['assisted', 'gokhan', 'tore']]
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Affinity\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
vocab_sorted = sorted(vocab.items(), key=lambda x:x[1], reverse=True)
print(vocab_sorted)
# Out:
# [('left', 3), ('attempt', 1), ('missed', 1), ('mladen', 1), ('petric', 1), ('hamburg', 1), ('footed', 1), ('shot', 1), ('side', 1), ('box', 1), ('high', 1), ('wide', 1), ('assisted', 1), ('gokhan', 1), ('tore', 1)]

# %%
word_to_index = {}
i = 0
for (word, frequency) in vocab_sorted:
    if frequency > 1:
        i += 1
        word_to_index[word] = i
    
print(word_to_index)
# Out:
# {'left': 1}

# %%
text_list = df.text.tolist()
# Out:
# ['Attempt missed. Mladen Petric (Hamburg) left footed shot from the left side of the box is high and wide to the left. Assisted by Gokhan Tore.',
#  'Corner,  Borussia Dortmund. Conceded by Dennis Diekmeier.',
#  'Corner,  Borussia Dortmund. Conceded by Heiko Westermann.',
#  'Foul by Sven Bender (Borussia Dortmund).',
#  'Gokhan Tore (Hamburg) wins a free kick in the defensive half.',
#  'Hand ball by Jose Paolo Guerrero (Hamburg).',
#  'Corner,  Hamburg. Conceded by Lukasz Piszczek.',
#  'Chris Lowe (Borussia Dortmund) wins a free kick in the defensive half.',
#  'Foul by Gojko Kacar (Hamburg).',
#  'Foul by Gokhan Tore (Hamburg).',
#  'Sven Bender (Borussia Dortmund) wins a free kick on the left wing.',
#  'Attempt missed. Shinji Kagawa (Borussia Dortmund) right footed shot from outside the box is close, but misses the top right corner. Assisted by Mario Gotze.',
#  'Foul by Gojko Kacar (Hamburg).',
#  'Goal!  Borussia Dortmund 1, Hamburg 0. Kevin Grosskreutz (Borussia Dortmund) left footed shot from the left side of the box to the bottom right corner. Assisted by Mario Gotze.',
#  'Attempt blocked. Mats Hummels (Borussia Dortmund) right footed shot from outside the box is blocked.',
#  'Foul by Sven Bender (Borussia Dortmund).',
#  'Mladen Petric (Hamburg) wins a free kick in the attacking half.',
#  'Attempt blocked. Tomas Rincon (Hamburg) right footed shot from outside the box is blocked.',
#  'Shinji Kagawa (Borussia Dortmund) hits the right post with a right footed shot from the centre of the box. Assisted by Lukasz Piszczek.',
#  'Corner,  Borussia Dortmund. Conceded by Dennis Diekmeier.',
#  'Attempt blocked. Ilkay Gundogan (Borussia Dortmund) left footed shot from outside the box is blocked.',
#  'Corner,  Borussia Dortmund. Conceded by Heiko Westermann.',
#  'Attempt saved. Mats Hummels (Borussia Dortmund) header from the centre of the box is saved in the centre of the goal. Assisted by Chris Lowe with a cross.',
#  'Lukasz Piszczek (Borussia Dortmund) wins a free kick in the defensive half.',
#  'Foul by Gokhan Tore (Hamburg).',
#  'Attempt missed. Shinji Kagawa (Borussia Dortmund) right footed shot from the left side of the box misses to the right. Assisted by Kevin Grosskreutz.',
#  'Goal!  Borussia Dortmund 2, Hamburg 0. Mario Gotze (Borussia Dortmund) right footed shot from the centre of the box to the centre of the goal. Assisted by Robert Lewandowski.',
#  'Foul by Kevin Grosskreutz (Borussia Dortmund).',
#  'Gokhan Tore (Hamburg) wins a free kick on the right wing.',
#  'Roman Weidenfeller (Borussia Dortmund) wins a free kick in the defensive half.',
#  'Corner,  Hamburg. Conceded by Ilkay Gundogan.',
#  'Foul by Gojko Kacar (Hamburg).',
#  'Foul by Robert Lewandowski (Borussia Dortmund).',
#  'Tomas Rincon (Hamburg) wins a free kick in the defensive half.',
#  'Attempt missed. Mario Gotze (Borussia Dortmund) right footed shot from the right side of the box is too high.',
#  'Foul by Felipe Santana (Borussia Dortmund).',
#  'Jose Paolo Guerrero (Hamburg) wins a free kick in the attacking half.',
#  'Attempt missed. Gokhan Tore (Hamburg) left footed shot from outside the box is too high.',
#  'Attempt missed. Robert Lewandowski (Borussia Dortmund) header from the left side of the box misses to the right. Assisted by Lukasz Piszczek with a cross.',
#  'Ilkay Gundogan (Borussia Dortmund) wins a free kick in the attacking half.',
#  'Foul by Gojko Kacar (Hamburg).',
#  'Substitution, Hamburg. Anis Ben-Hatira replaces Jose Paolo Guerrero because of an injury.',
#  'Offside, Borussia Dortmund. Mats Hummels tries a through ball, but Shinji Kagawa is caught offside.',
#  'Attempt missed. Ilkay Gundogan (Borussia Dortmund) right footed shot from the right side of the box misses to the left. Assisted by Mario Gotze following a fast break.',
#  'Michael Mancienne (Hamburg) is shown the yellow card.',
#  'Shinji Kagawa (Borussia Dortmund) wins a free kick in the attacking half.',
#  'Substitution, Hamburg. Marcell Jansen replaces Eljero Elia.',
#  'Foul by Marcell Jansen (Hamburg).',
#  'Corner,  Borussia Dortmund. Conceded by Tomas Rincon.',
#  'Attempt saved. Kevin Grosskreutz (Borussia Dortmund) right footed shot from the centre of the box is saved in the top centre of the goal. Assisted by Mario Gotze.',
#  'Goal!  Borussia Dortmund 3, Hamburg 0. Kevin Grosskreutz (Borussia Dortmund) right footed shot from very close range to the bottom right corner following a corner.',
#  'Foul by Chris Lowe (Borussia Dortmund).',
#  'Tomas Rincon (Hamburg) wins a free kick in the defensive half.',
#  'Foul by Tomas Rincon (Hamburg).',
#  'Shinji Kagawa (Borussia Dortmund) wins a free kick on the left wing.',
#  'Foul by Marcell Jansen (Hamburg).',
#  'Roman Weidenfeller (Borussia Dortmund) wins a free kick in the defensive half.',
#  'Corner,  Borussia Dortmund. Conceded by Heiko Westermann.',
#  'Attempt blocked. Shinji Kagawa (Borussia Dortmund) right footed shot from outside the box is blocked. Assisted by Kevin Grosskreutz with a headed pass.',
#  'Corner,  Borussia Dortmund. Conceded by Marcell Jansen.',
#  'Dennis Diekmeier (Hamburg) wins a free kick in the defensive half.',
#  'Foul by Sven Bender (Borussia Dortmund).',
#  'Shinji Kagawa (Borussia Dortmund) wins a free kick in the defensive half.',
#  'Corner,  Hamburg. Conceded by Felipe Santana.',
#  'Foul by Shinji Kagawa (Borussia Dortmund).',
#  'Foul by Dennis Diekmeier (Hamburg).',
#  'Mario Gotze (Borussia Dortmund) wins a free kick in the attacking half.',
#  'Anis Ben-Hatira (Hamburg) wins a free kick in the defensive half.',
#  'Foul by Tomas Rincon (Hamburg).',
#  'Attempt blocked. Marcell Jansen (Hamburg) left footed shot from long range on the left is blocked.',
#  'Corner,  Hamburg. Conceded by Lukasz Piszczek.',
#  'Attempt blocked. Michael Mancienne (Hamburg) right footed shot from the centre of the box is blocked. Assisted by Gokhan Tore with a cross.',
#  'Mario Gotze (Borussia Dortmund) wins a free kick in the attacking half.',
#  'Offside, Hamburg. Tomas Rincon tries a through ball, but Gokhan Tore is caught offside.',
#  'Foul by Gojko Kacar (Hamburg).',
#  'Ilkay Gundogan (Borussia Dortmund) wins a free kick in the attacking half.',
#  'Gojko Kacar (Hamburg) is shown the yellow card for a bad foul.',
#  'Foul by Tomas Rincon (Hamburg).',
#  'Foul by Ilkay Gundogan (Borussia Dortmund).',
#  'Tomas Rincon (Hamburg) is shown the yellow card for a bad foul.',
#  'Mladen Petric (Hamburg) wins a free kick in the defensive half.',
#  'Foul by Kevin Grosskreutz (Borussia Dortmund).',
#  'Offside, Hamburg. Heiko Westermann tries a through ball, but Anis Ben-Hatira is caught offside.',
#  'Substitution, Hamburg. Robert Tesche replaces Gojko Kacar.',
#  'Gokhan Tore (Hamburg) wins a free kick in the defensive half.',
#  'Corner,  Hamburg. Conceded by Chris Lowe.',
#  'Foul by Robert Tesche (Hamburg).',
#  'Robert Lewandowski (Borussia Dortmund) wins a free kick in the defensive half.',
#  'Substitution, Borussia Dortmund. Ivan Perisic replaces Chris Lowe.',
#  'Substitution, Borussia Dortmund. Jakub Blaszczykowski replaces Mario Gotze.',
#  'Corner,  Hamburg. Conceded by Lukasz Piszczek.',
#  'Attempt blocked. Marcell Jansen (Hamburg) header from the centre of the box is blocked. Assisted by Anis Ben-Hatira with a cross.',
#  'Goal!  Borussia Dortmund 3, Hamburg 1. Robert Tesche (Hamburg) left footed shot from the centre of the box to the bottom left corner following a corner.',
#  'Attempt saved. Marcell Jansen (Hamburg) left footed shot from the left side of the box is saved in the centre of the goal. Assisted by Gokhan Tore.',
#  'Foul by Heiko Westermann (Hamburg).',
#  'Robert Lewandowski (Borussia Dortmund) wins a free kick in the attacking half.',
#  'Attempt missed. Ivan Perisic (Borussia Dortmund) right footed shot from outside the box is close, but misses to the right from a direct free kick.',
#  'Foul by Marcell Jansen (Hamburg).',
#  'Lukasz Piszczek (Borussia Dortmund) wins a free kick in the defensive half.',
#  'Foul by Robert Lewandowski (Borussia Dortmund).',
#  'Dennis Diekmeier (Hamburg) wins a free kick in the defensive half.',
#  'Robert Lewandowski (Borussia Dortmund) is shown the yellow card for a bad foul.',
#  'Offside, Hamburg. Marcell Jansen tries a through ball, but Dennis Aogo is caught offside.',
#  'Attempt missed. Kevin Grosskreutz (Borussia Dortmund) right footed shot from more than 35 yards is too high.',
#  'Foul by Felipe Santana (Borussia Dortmund).',
#  'Mladen Petric (Hamburg) wins a free kick on the left wing.',
#  'Ilkay Gundogan (Borussia Dortmund) wins a free kick in the attacking half.',
#  'Substitution, Borussia Dortmund. Sebastian Kehl replaces Shinji Kagawa.',
#  'Corner,  Hamburg. Conceded by Sven Bender.',
#  'Foul by Robert Tesche (Hamburg).',
#  'Sascha Molders (FC Augsburg) wins a free kick in the attacking half.',
#  'Foul by Heiko Butscher (SC Freiburg).',
#  'Attempt saved. Jonas De Roeck (FC Augsburg) header from the centre of the box is saved in the bottom left corner. Assisted by Daniel Baier.',
#  'Sascha Molders (FC Augsburg) wins a free kick in the defensive half.',
#  'Foul by Mensur Mujdza (SC Freiburg).',
#  'Foul by Lorenzo Davids (FC Augsburg).',
#  'Yacine Abdessadki (SC Freiburg) wins a free kick in the attacking half.',
#  'Foul by Marcel de Jong (FC Augsburg).',
#  'Marcel de Jong (FC Augsburg) is shown the yellow card for a bad foul.',
#  'Mensur Mujdza (SC Freiburg) wins a free kick on the right wing.',
#  'Tobias Werner (FC Augsburg) wins a free kick in the attacking half.',
#  'Foul by Julian Schuster (SC Freiburg).',
#  'Foul by Tobias Werner (FC Augsburg).',
#  'Cedric Makiadi (SC Freiburg) wins a free kick in the defensive half.',
#  'Oliver Barth (SC Freiburg) wins a free kick in the defensive half.',
#  'Tobias Werner (FC Augsburg) is shown the yellow card for a bad foul.',
#  'Uwe Mohrle (FC Augsburg) wins a free kick in the defensive half.',
#  'Foul by Heiko Butscher (SC Freiburg).',
#  'Sascha Molders (FC Augsburg) wins a free kick in the attacking half.',
#  'Foul by Lorenzo Davids (FC Augsburg).',
#  'Foul by Heiko Butscher (SC Freiburg).',
#  'Cedric Makiadi (SC Freiburg) wins a free kick in the attacking half.',
#  'Attempt missed. Daniel Caligiuri (SC Freiburg) right footed shot from the right side of the box misses to the left. Assisted by Mensur Mujdza.',
#  'Corner,  SC Freiburg. Conceded by Uwe Mohrle.',
#  'Daniel Baier (FC Augsburg) wins a free kick on the left wing.',
#  'Foul by Oliver Barth (SC Freiburg).',
#  'Attempt missed. Marcel de Jong (FC Augsburg) left footed shot from outside the box is too high following a set piece situation.',
#  'Foul by Jan-Ingwer Callsen-Bracker (FC Augsburg).',
#  'Johannes Flum (SC Freiburg) wins a free kick in the attacking half.',
#  'Daniel Baier (FC Augsburg) wins a free kick in the defensive half.',
#  'Attempt blocked. Cedric Makiadi (SC Freiburg) right footed shot from outside the box is blocked. Assisted by Oliver Barth.',
#  'Foul by Daniel Caligiuri (SC Freiburg).',
#  'Corner,  FC Augsburg. Conceded by Mensur Mujdza.',
#  'Jonas De Roeck (FC Augsburg) wins a free kick in the defensive half.',
#  'Foul by Daniel Caligiuri (SC Freiburg).',
#  'Daniel Baier (FC Augsburg) wins a free kick in the defensive half.',
#  'Foul by Julian Schuster (SC Freiburg).',
#  'Attempt saved. Marcel Ndjeng (FC Augsburg) right footed shot from the left side of the box is saved in the bottom left corner. Assisted by Daniel Baier.',
#  'Tobias Werner (FC Augsburg) wins a free kick on the right wing.',
#  'Attempt saved. Sascha Molders (FC Augsburg) right footed shot from very close range is saved in the centre of the goal. Assisted by Marcel de Jong with a cross.',
#  'Foul by Yacine Abdessadki (SC Freiburg).',
#  'Marcel de Jong (FC Augsburg) wins a free kick in the attacking half.',
#  'Foul by Oliver Barth (SC Freiburg).',
#  'Oliver Barth (SC Freiburg) is shown the yellow card for a bad foul.',
#  'Marcel Ndjeng (FC Augsburg) wins a free kick in the defensive half.',
#  'Foul by Yacine Abdessadki (SC Freiburg).',
#  'Marcel de Jong (FC Augsburg) wins a free kick on the left wing.',
#  'Foul by Daniel Caligiuri (SC Freiburg).',
#  'Foul by Jonas De Roeck (FC Augsburg).',
#  'Attempt missed. Marcel Ndjeng (FC Augsburg) right footed shot from outside the box misses to the left.',
#  'Oliver Barth (SC Freiburg) wins a free kick in the defensive half.',
#  'Corner,  FC Augsburg. Conceded by Yacine Abdessadki.',
#  'Attempt missed. Marcel de Jong (FC Augsburg) left footed shot from outside the box is too high. Assisted by Jan-Ingwer Callsen-Bracker following a corner.',
#  'Foul by Jonas De Roeck (FC Augsburg).',
#  'Daniel Caligiuri (SC Freiburg) wins a free kick in the attacking half.',
#  'Attempt blocked. Julian Schuster (SC Freiburg) right footed shot from outside the box is blocked.',
#  'Tobias Werner (FC Augsburg) wins a free kick in the defensive half.',
#  'Corner,  SC Freiburg. Conceded by Lorenzo Davids.',
#  'Foul by Cedric Makiadi (SC Freiburg).',
#  'Foul by Jonas De Roeck (FC Augsburg).',
#  'Daniel Caligiuri (SC Freiburg) wins a free kick in the attacking half.',
#  'Attempt saved. Cedric Makiadi (SC Freiburg) right footed shot from a difficult angle on the left is saved in the bottom left corner. Assisted by Johannes Flum.',
#  'Tobias Werner (FC Augsburg) wins a free kick in the defensive half.',
#  'Substitution, FC Augsburg. Axel Bellinghausen replaces Tobias Werner.',
#  'Foul by Julian Schuster (SC Freiburg).',
#  'Goal!  FC Augsburg 0, SC Freiburg 1. Papiss Demba Cisse (SC Freiburg) right footed shot from outside the box to the bottom left corner. Assisted by Felix Bastians following a fast break.',
#  'Foul by Jan-Ingwer Callsen-Bracker (FC Augsburg).',
#  'Cedric Makiadi (SC Freiburg) wins a free kick in the defensive half.',
#  'Marcel Ndjeng (FC Augsburg) wins a free kick on the right wing.',
#  'Foul by Julian Schuster (SC Freiburg).',
#  'Jonas De Roeck (FC Augsburg) wins a free kick in the defensive half.',
#  'Foul by Mensur Mujdza (SC Freiburg).',
#  'Corner,  FC Augsburg. Conceded by Oliver Barth.',
#  'Goal!  FC Augsburg 1, SC Freiburg 1. Sascha Molders (FC Augsburg) header from the centre of the box to the top left corner. Assisted by Axel Bellinghausen with a cross.',
#  'Goal!  FC Augsburg 1, SC Freiburg 2. Cedric Makiadi (SC Freiburg) header from the centre of the box to the top left corner. Assisted by Mensur Mujdza with a cross.',
#  'Corner,  SC Freiburg. Conceded by Jonas De Roeck.',
#  'Attempt blocked. Daniel Caligiuri (SC Freiburg) right footed shot from outside the box is blocked. Assisted by Papiss Demba Cisse.',
#  'Axel Bellinghausen (FC Augsburg) wins a free kick on the left wing.',
#  'Foul by Marcel de Jong (FC Augsburg).',
#  'Foul by Julian Schuster (SC Freiburg).',
#  'Papiss Demba Cisse (SC Freiburg) wins a free kick in the defensive half.',
#  'Foul by Daniel Caligiuri (SC Freiburg).',
#  'Daniel Caligiuri (SC Freiburg) is shown the yellow card for a bad foul.',
#  'Corner,  FC Augsburg. Conceded by Heiko Butscher.',
#  'Attempt saved. Sascha Molders (FC Augsburg) header from the centre of the box is saved in the centre of the goal. Assisted by Daniel Baier with a cross.',
#  'Substitution, FC Augsburg. Akaki Gogia replaces Marcel Ndjeng.',
#  'Axel Bellinghausen (FC Augsburg) wins a free kick on the left wing.',
#  'Foul by Johannes Flum (SC Freiburg).',
#  'Attempt missed. Mensur Mujdza (SC Freiburg) left footed shot from outside the box is close, but misses to the right. Assisted by Daniel Caligiuri following a fast break.',
#  'Axel Bellinghausen (FC Augsburg) wins a free kick in the attacking half.',
#  'Akaki Gogia (FC Augsburg) wins a free kick on the right wing.',
#  'Foul by Daniel Caligiuri (SC Freiburg).',
#  'Foul by Felix Bastians (SC Freiburg).',
#  'Marcel de Jong (FC Augsburg) wins a free kick on the left wing.',
#  'Attempt saved. Sascha Molders (FC Augsburg) header from the centre of the box is saved in the bottom right corner. Assisted by Daniel Baier with a cross.',
#  'Foul by Cedric Makiadi (SC Freiburg).',
#  'Substitution, FC Augsburg. Stephan Hain replaces Lorenzo Davids.',
#  'Foul by Uwe Mohrle (FC Augsburg).',
#  'Papiss Demba Cisse (SC Freiburg) wins a free kick in the attacking half.',
#  'Foul by Daniel Baier (FC Augsburg).',
#  'Julian Schuster (SC Freiburg) wins a free kick in the defensive half.',
#  'Goal!  FC Augsburg 2, SC Freiburg 2. Sascha Molders (FC Augsburg) header from the centre of the box to the bottom left corner. Assisted by Akaki Gogia with a cross.',
#  'Axel Bellinghausen (FC Augsburg) wins a free kick on the left wing.',
#  'Foul by Mensur Mujdza (SC Freiburg).',
#  'Substitution, SC Freiburg. Anton Putsila replaces Cedric Makiadi because of an injury.',
#  'Foul by Sascha Molders (FC Augsburg).',
#  'Corner,  FC Augsburg. Conceded by Julian Schuster.',
#  'Heiko Butscher (SC Freiburg) wins a free kick in the defensive half.',
#  'Mensur Mujdza (SC Freiburg) is shown the yellow card.',
#  'Foul by Jan-Ingwer Callsen-Bracker (FC Augsburg).',
#  'Anton Putsila (SC Freiburg) wins a free kick on the left wing.',
#  'Corner,  SC Freiburg. Conceded by Jonas De Roeck.',
#  'Substitution, SC Freiburg. Garra Dembele replaces Daniel Caligiuri.',
#  'Garra Dembele (SC Freiburg) wins a free kick in the defensive half.',
#  'Foul by Axel Bellinghausen (FC Augsburg).',
#  'Offside, FC Augsburg. Simon Jentzsch tries a through ball, but Stephan Hain is caught offside.',
#  'Daniel Baier (FC Augsburg) wins a free kick in the defensive half.',
#  'Attempt blocked. Sascha Molders (FC Augsburg) left footed shot from outside the box is blocked. Assisted by Jan-Ingwer Callsen-Bracker with a headed pass.',
#  'Mensur Mujdza (SC Freiburg) wins a free kick on the right wing.',
#  'Attempt saved. Garra Dembele (SC Freiburg) right footed shot from a difficult angle on the right is saved in the bottom right corner. Assisted by Papiss Demba Cisse.',
#  'Foul by Johannes Flum (SC Freiburg).',
#  'Johannes Flum (SC Freiburg) is shown the yellow card for a bad foul.',
#  'Per Mertesacker (SV Werder Bremen) wins a free kick in the defensive half.',
#  'Foul by Richard Sukuta-Pasu (Kaiserslautern).',
#  'Per Mertesacker (SV Werder Bremen) wins a free kick in the defensive half.',
#  'Foul by Richard Sukuta-Pasu (Kaiserslautern).',
#  'Clemens Fritz (SV Werder Bremen) wins a free kick in the defensive half.',
#  'Foul by Florian Dick (Kaiserslautern).',
#  'Attempt saved. Lennart Thy (SV Werder Bremen) left footed shot from the left side of the box is saved in the bottom right corner. Assisted by Aaron Hunt with a through ball.',
#  'Offside, Kaiserslautern. Mathias Abel tries a through ball, but Richard Sukuta-Pasu is caught offside.',
#  'Foul by Sokratis (SV Werder Bremen).',
#  'Foul by Philipp Bargfrede (SV Werder Bremen).',
#  'Ivo Ilicevic (Kaiserslautern) wins a free kick on the left wing.',
#  'Leon Jessen (Kaiserslautern) wins a free kick on the left wing.',
#  'Marko Marin (SV Werder Bremen) wins a free kick in the attacking half.',
#  'Corner,  SV Werder Bremen. Conceded by Rodnei.',
#  'Attempt blocked. Markus Rosenberg (SV Werder Bremen) left footed shot from the right side of the six yard box is blocked.',
#  'Foul by Thanos Petsos (Kaiserslautern).',
#  'Corner,  Kaiserslautern. Conceded by Andreas Wolf.',
#  'Lennart Thy (SV Werder Bremen) wins a free kick in the defensive half.',
#  'Foul by Mathias Abel (Kaiserslautern).',
#  'Hand ball by Olcay Sahan (Kaiserslautern).',
#  'Offside, Kaiserslautern. Pierre De Wit tries a through ball, but Ivo Ilicevic is caught offside.',
#  'Offside, Kaiserslautern. Olcay Sahan tries a through ball, but Pierre De Wit is caught offside.',
#  'Marko Marin (SV Werder Bremen) wins a free kick in the attacking half.',
#  'Foul by Florian Dick (Kaiserslautern).',
#  'Clemens Fritz (SV Werder Bremen) wins a free kick in the attacking half.',
#  'Foul by Richard Sukuta-Pasu (Kaiserslautern).',
#  'Richard Sukuta-Pasu (Kaiserslautern) is shown the yellow card for a bad foul.',
#  'Aaron Hunt (SV Werder Bremen) wins a free kick in the attacking half.',
#  'Foul by Andreas Wolf (SV Werder Bremen).',
#  'Foul by Christian Tiffert (Kaiserslautern).',
#  'Richard Sukuta-Pasu (Kaiserslautern) wins a free kick in the defensive half.',
#  'Florian Dick (Kaiserslautern) wins a free kick in the defensive half.',
#  'Olcay Sahan (Kaiserslautern) wins a free kick on the right wing.',
#  'Offside, Kaiserslautern. Ivo Ilicevic tries a through ball, but Pierre De Wit is caught offside.',
#  'Attempt saved. Aaron Hunt (SV Werder Bremen) left footed shot from outside the box is saved in the bottom right corner. Assisted by Marko Marin.',
#  'Offside, SV Werder Bremen. Markus Rosenberg tries a through ball, but Lennart Thy is caught offside.',
#  'Andreas Wolf (SV Werder Bremen) wins a free kick in the attacking half.',
#  'Markus Rosenberg (SV Werder Bremen) wins a free kick on the right wing.',
#  'Foul by Richard Sukuta-Pasu (Kaiserslautern).',
#  'Foul by Rodnei (Kaiserslautern).',
#  'Clemens Fritz (SV Werder Bremen) wins a free kick in the defensive half.',
#  'Foul by Florian Dick (Kaiserslautern).',
#  'Corner,  Kaiserslautern. Conceded by Sokratis.',
#  'Attempt blocked. Markus Rosenberg (SV Werder Bremen) right footed shot from the centre of the box is blocked. Assisted by Lennart Thy.',
#  'Lennart Thy (SV Werder Bremen) wins a free kick in the attacking half.',
#  'Foul by Mathias Abel (Kaiserslautern).',
#  'Marko Marin (SV Werder Bremen) wins a free kick in the attacking half.',
#  'Foul by Christian Tiffert (Kaiserslautern).',
#  'Offside, SV Werder Bremen. Marko Marin tries a through ball, but Per Mertesacker is caught offside.',
#  'Attempt saved. Florian Dick (Kaiserslautern) right footed shot from outside the box is saved in the bottom left corner. Assisted by Christian Tiffert.',
#  'Foul by Clemens Fritz (SV Werder Bremen).',
#  'Thanos Petsos (Kaiserslautern) wins a free kick in the defensive half.',
#  'Lukas Schmitz (SV Werder Bremen) wins a free kick in the defensive half.',
#  'Offside, SV Werder Bremen. Philipp Bargfrede tries a through ball, but Lennart Thy is caught offside.',
#  'Foul by Olcay Sahan (Kaiserslautern).',
#  'Attempt missed. Clemens Fritz (SV Werder Bremen) right footed shot from outside the box is close, but misses to the left. Assisted by Marko Marin.',
#  'Foul by Lukas Schmitz (SV Werder Bremen).',
#  'Olcay Sahan (Kaiserslautern) wins a free kick on the right wing.',
#  'Corner,  SV Werder Bremen. Conceded by Pierre De Wit.',
#  'Marko Marin (SV Werder Bremen) wins a free kick in the attacking half.',
#  'Attempt missed. Aaron Hunt (SV Werder Bremen) left footed shot from outside the box is just a bit too high from a direct free kick.',
#  'Substitution, SV Werder Bremen. Mehmet Ekici replaces Philipp Bargfrede.',
#  'Foul by Rodnei (Kaiserslautern).',
#  'Substitution, Kaiserslautern. Itay Shechter replaces Richard Sukuta-Pasu.',
#  'Andreas Wolf (SV Werder Bremen) wins a free kick in the defensive half.',
#  'Foul by Christian Tiffert (Kaiserslautern).',
#  'Attempt blocked. Marko Marin (SV Werder Bremen) right footed shot from the right side of the box is blocked. Assisted by Markus Rosenberg.',
#  'Corner,  SV Werder Bremen. Conceded by Mathias Abel.',
#  'Attempt missed. Sokratis (SV Werder Bremen) header from very close range is too high. Assisted by Mehmet Ekici with a cross following a corner.',
#  'Offside, SV Werder Bremen. Lennart Thy tries a through ball, but Marko Marin is caught offside.',
#  'Offside, Kaiserslautern. Ivo Ilicevic tries a through ball, but Itay Shechter is caught offside.',
#  'Attempt saved. Itay Shechter (Kaiserslautern) header from the centre of the box is saved in the top centre of the goal. Assisted by Olcay Sahan with a cross.',
#  'Attempt missed. Ivo Ilicevic (Kaiserslautern) right footed shot from outside the box is high and wide to the right. Assisted by Olcay Sahan.',
#  'Foul by Per Mertesacker (SV Werder Bremen).',
#  'Itay Shechter (Kaiserslautern) wins a free kick on the left wing.',
#  'Offside, SV Werder Bremen. Markus Rosenberg tries a through ball, but Marko Marin is caught offside.',
#  'Mehmet Ekici (SV Werder Bremen) wins a free kick in the defensive half.',
#  'Foul by Christian Tiffert (Kaiserslautern).',
#  'Ivo Ilicevic (Kaiserslautern) hits the bar with a right footed shot from the centre of the box. Assisted by Florian Dick with a cross.',
#  'Corner,  Kaiserslautern. Conceded by Per Mertesacker.',
#  'Aaron Hunt (SV Werder Bremen) wins a free kick on the left wing.',
#  'Attempt blocked. Marko Marin (SV Werder Bremen) right footed shot from the left side of the box is blocked. Assisted by Lukas Schmitz.',
#  'Per Mertesacker (SV Werder Bremen) wins a free kick in the defensive half.',
#  'Foul by Itay Shechter (Kaiserslautern).',
#  'Substitution, SV Werder Bremen. Wesley replaces Marko Marin.',
#  'Goal!  SV Werder Bremen 1, Kaiserslautern 0. Markus Rosenberg (SV Werder Bremen) right footed shot from very close range to the bottom right corner.',
#  'Attempt saved. Lukas Schmitz (SV Werder Bremen) left footed shot from outside the box is saved in the bottom right corner. Assisted by Clemens Fritz.',
#  'Aaron Hunt (SV Werder Bremen) wins a free kick in the defensive half.',
#  'Foul by Itay Shechter (Kaiserslautern).',
#  'Markus Rosenberg (SV Werder Bremen) wins a free kick in the attacking half.',
#  'Foul by Christian Tiffert (Kaiserslautern).',
#  'Substitution, Kaiserslautern. Konstantinos Fortounis replaces Pierre De Wit.',
#  'Foul by Lukas Schmitz (SV Werder Bremen).',
#  'Christian Tiffert (Kaiserslautern) wins a free kick on the right wing.',
#  'Attempt blocked. Clemens Fritz (SV Werder Bremen) right footed shot from outside the box is blocked. Assisted by Aaron Hunt with a headed pass.',
#  'Attempt blocked. Aaron Hunt (SV Werder Bremen) left footed shot from outside the box is blocked.',
#  'Corner,  SV Werder Bremen. Conceded by Thanos Petsos.',
#  'Foul by Wesley (SV Werder Bremen).',
#  'Wesley (SV Werder Bremen) is shown the yellow card for a bad foul.',
#  'Florian Dick (Kaiserslautern) wins a free kick in the attacking half.',
#  'Corner,  Kaiserslautern. Conceded by Clemens Fritz.',
#  'Clemens Fritz (SV Werder Bremen) wins a free kick in the defensive half.',
#  'Attempt blocked. Olcay Sahan (Kaiserslautern) right footed shot from outside the box is blocked.',
#  'Foul by Florian Dick (Kaiserslautern).',
#  'Florian Dick (Kaiserslautern) is shown the yellow card for a bad foul.',
#  'Wesley (SV Werder Bremen) wins a free kick on the left wing.',
#  'Foul by Mathias Abel (Kaiserslautern).',
#  'Attempt blocked. Aaron Hunt (SV Werder Bremen) right footed shot from the centre of the box is blocked.',
#  'Foul by Sokratis (SV Werder Bremen).',
#  'Ivo Ilicevic (Kaiserslautern) wins a free kick on the left wing.',
#  'Offside, SV Werder Bremen. Aaron Hunt tries a through ball, but Lennart Thy is caught offside.',
#  'Attempt missed. Olcay Sahan (Kaiserslautern) right footed shot from outside the box misses to the left.',
#  'Aaron Hunt (SV Werder Bremen) wins a free kick on the right wing.',
#  'Attempt blocked. Aaron Hunt (SV Werder Bremen) left footed shot from long range on the right is blocked.',
#  'Foul by Rodnei (Kaiserslautern).',
#  'Corner,  SV Werder Bremen. Conceded by Mathias Abel.',
#  'Attempt blocked. Sokratis (SV Werder Bremen) header from very close range is blocked. Assisted by Mehmet Ekici with a cross.',
#  'Corner,  SV Werder Bremen. Conceded by Rodnei.',
#  'Attempt missed. Per Mertesacker (SV Werder Bremen) header from very close range misses to the left. Assisted by Mehmet Ekici with a cross following a corner.',
#  'Foul by Clemens Fritz (SV Werder Bremen).',
#  'Olcay Sahan (Kaiserslautern) wins a free kick in the defensive half.',
#  'Goal!  SV Werder Bremen 2, Kaiserslautern 0. Markus Rosenberg (SV Werder Bremen) header from very close range to the bottom right corner. Assisted by Wesley with a cross following a fast break.',
#  'Substitution, Kaiserslautern. Martin Amedick replaces Thanos Petsos.',
#  'Foul by Per Mertesacker (SV Werder Bremen).',
#  'Itay Shechter (Kaiserslautern) wins a free kick in the attacking half.',
#  'Offside, Kaiserslautern. Itay Shechter tries a through ball, but Ivo Ilicevic is caught offside.',
#  'Sokratis (SV Werder Bremen) wins a free kick in the defensive half.',
#  'Foul by Ivo Ilicevic (Kaiserslautern).',
#  'Markus Rosenberg (SV Werder Bremen) hits the right post with a right footed shot from the centre of the box. Assisted by Aaron Hunt following a fast break.',
#  'Foul by Sokratis (SV Werder Bremen).',
#  'Martin Amedick (Kaiserslautern) wins a free kick on the left wing.',
#  'Tim Wiese (SV Werder Bremen) wins a free kick in the defensive half.',
#  'Foul by Rodnei (Kaiserslautern).',
#  'Attempt blocked. Ivo Ilicevic (Kaiserslautern) right footed shot from the left side of the box is blocked. Assisted by Konstantinos Fortounis.',
#  'Corner,  Kaiserslautern. Conceded by Lukas Schmitz.',
#  'Attempt blocked. Olcay Sahan (Kaiserslautern) right footed shot from outside the box is blocked.',
#  'Attempt saved. Rodnei (Kaiserslautern) right footed shot from very close range is saved in the centre of the goal. Assisted by Martin Amedick with a headed pass.',
#  'Bruno Ecuele Manga (Lorient) wins a free kick in the defensive half.',
#  'Yann Jouffre (Lorient) wins a free kick on the right wing.',
#  'Foul by Blaise Matuidi (Paris Saint Germain).',
#  'Lucas Mareque (Lorient) wins a free kick on the left wing.',
#  'Foul by JA©rA©my Menez (Paris Saint Germain).',
#  'Attempt blocked. Julien Quercia (Lorient) right footed shot from outside the box is blocked. Assisted by Lucas Mareque.',
#  'Guillaume Hoarau (Paris Saint Germain) wins a free kick on the right wing.',
#  'Arnold Mvuemba (Lorient) wins a free kick in the defensive half.',
#  'Foul by JA©rA©my Menez (Paris Saint Germain).',
#  'Attempt missed. KA©vin Monnet-Paquet (Lorient) left footed shot from the left side of the six yard box misses to the right. Assisted by Julien Quercia with a cross.',
#  'Attempt saved. Yann Jouffre (Lorient) right footed shot from the centre of the box is saved in the bottom right corner. Assisted by Julien Quercia.',
#  'KA©vin Monnet-Paquet (Lorient) wins a free kick in the attacking half.',
#  'Foul by Milan Bisevac (Paris Saint Germain).',
#  'Foul by Arnold Mvuemba (Lorient).',
#  'ClA©ment Chantome (Paris Saint Germain) wins a free kick in the attacking half.',
#  'Attempt missed. Kevin Gameiro (Paris Saint Germain) right footed shot from outside the box is close, but misses to the left. Assisted by Guillaume Hoarau with a headed pass.',
#  'Offside, Paris Saint Germain. Milan Bisevac tries a through ball, but NenAª is caught offside.',
#  'Lucas Mareque (Lorient) wins a free kick on the left wing.',
#  'Foul by Guillaume Hoarau (Paris Saint Germain).',
#  'Offside, Lorient. Yann Jouffre tries a through ball, but Julien Quercia is caught offside.',
#  'Jacques-Alaixys Romao (Lorient) wins a free kick in the defensive half.',
#  'Foul by JA©rA©my Menez (Paris Saint Germain).',
#  'Corner,  Lorient. Conceded by Mamadou Sakho.',
#  'Foul by Yann Jouffre (Lorient).',
#  'JA©rA©my Menez (Paris Saint Germain) wins a free kick in the defensive half.',
#  'Yann Jouffre (Lorient) is shown the yellow card for a bad foul.',
#  'Attempt missed. Kevin Gameiro (Paris Saint Germain) header from the centre of the box misses to the left. Assisted by Christophe Jallet with a cross.',
#  'Julien Quercia (Lorient) wins a free kick on the right wing.',
#  'Foul by Mamadou Sakho (Paris Saint Germain).',
#  'Goal!  Paris Saint Germain 0, Lorient 1. Julien Quercia (Lorient) right footed shot from the left side of the six yard box to the bottom left corner. Assisted by Yann Jouffre with a cross following a set piece situation.',
#  'Mathieu Coutadeur (Lorient) wins a free kick on the left wing.',
#  'Foul by Christophe Jallet (Paris Saint Germain).',
#  'Offside, Lorient. Mathieu Coutadeur tries a through ball, but Julien Quercia is caught offside.',
#  'Foul by Lucas Mareque (Lorient).',
#  'JA©rA©my Menez (Paris Saint Germain) wins a free kick in the attacking half.',
#  'Offside, Lorient. Lucas Mareque tries a through ball, but Julien Quercia is caught offside.',
#  'Offside, Paris Saint Germain. NenAª tries a through ball, but Kevin Gameiro is caught offside.',
#  'Yann Jouffre (Lorient) wins a free kick on the right wing.',
#  'Foul by ClA©ment Chantome (Paris Saint Germain).',
#  'ClA©ment Chantome (Paris Saint Germain) is shown the yellow card for a bad foul.',
#  'Corner,  Lorient. Conceded by Mamadou Sakho.',
#  'Attempt missed. NenAª (Paris Saint Germain) left footed shot from the left side of the box is just a bit too high. Assisted by Kevin Gameiro with a through ball.',
#  'Offside, Lorient. Mathieu Coutadeur tries a through ball, but Yann Jouffre is caught offside.',
#  'Corner,  Paris Saint Germain. Conceded by GrA©gory Bourillon.',
#  'Corner,  Paris Saint Germain. Conceded by Bruno Ecuele Manga.',
#  'Attempt blocked. NenAª (Paris Saint Germain) left footed shot from outside the box is blocked. Assisted by Christophe Jallet.',
#  'Offside, Paris Saint Germain. NenAª tries a through ball, but Guillaume Hoarau is caught offside.',
#  'KA©vin Monnet-Paquet (Lorient) wins a free kick on the right wing.',
#  'Foul by Siaka TiA©nA© (Paris Saint Germain).',
#  'Foul by Pedrinho (Lorient).',
#  'NenAª (Paris Saint Germain) wins a free kick on the left wing.',
#  'Attempt blocked. Mamadou Sakho (Paris Saint Germain) header from the centre of the box is blocked. Assisted by NenAª with a cross.',
#  'Attempt missed. NenAª (Paris Saint Germain) left footed shot from outside the box misses to the right. Assisted by Kevin Gameiro.',
#  'Jacques-Alaixys Romao (Lorient) wins a free kick in the defensive half.',
#  'Foul by JA©rA©my Menez (Paris Saint Germain).',
#  'Offside, Paris Saint Germain. Kevin Gameiro tries a through ball, but Guillaume Hoarau is caught offside.',
#  'Attempt missed. NenAª (Paris Saint Germain) left footed shot from outside the box is just a bit too high. Assisted by Blaise Matuidi.',
#  'Corner,  Paris Saint Germain. Conceded by Pedrinho.',
#  'Pedrinho (Lorient) wins a free kick on the right wing.',
#  'Foul by NenAª (Paris Saint Germain).',
#  'Corner,  Lorient. Conceded by Mamadou Sakho.',
#  'Attempt missed. Yann Jouffre (Lorient) left footed shot from outside the box misses to the left. Assisted by Arnold Mvuemba with a headed pass following a corner.',
#  'Substitution, Paris Saint Germain. Mathieu Bodmer replaces Guillaume Hoarau.',
#  'Jacques-Alaixys Romao (Lorient) wins a free kick in the defensive half.',
#  'Foul by Mathieu Bodmer (Paris Saint Germain).',
#  'Yann Jouffre (Lorient) wins a free kick on the right wing.',
#  'Foul by Siaka TiA©nA© (Paris Saint Germain).',
#  'Attempt saved. Bruno Ecuele Manga (Lorient) right footed shot from outside the box is saved in the bottom right corner.',
#  'Corner,  Lorient. Conceded by Siaka TiA©nA©.',
#  'Attempt blocked. Jacques-Alaixys Romao (Lorient) header from the centre of the box is blocked. Assisted by Yann Jouffre with a cross.',
#  'Corner,  Lorient. Conceded by ClA©ment Chantome.',
#  'Attempt saved. NenAª (Paris Saint Germain) right footed shot from outside the box is saved in the centre of the goal. Assisted by Blaise Matuidi.',
#  'NenAª (Paris Saint Germain) wins a free kick in the attacking half.',
#  'Mathieu Coutadeur (Lorient) wins a free kick in the defensive half.',
#  'Foul by Blaise Matuidi (Paris Saint Germain).',
#  'Offside, Lorient. Yann Jouffre tries a through ball, but Julien Quercia is caught offside.',
#  'Foul by Lucas Mareque (Lorient).',
#  'Christophe Jallet (Paris Saint Germain) wins a free kick on the right wing.',
#  'Yann Jouffre (Lorient) wins a free kick on the left wing.',
#  'Foul by Christophe Jallet (Paris Saint Germain).',
#  'Mathieu Coutadeur (Lorient) wins a free kick in the attacking half.',
#  'Foul by Mamadou Sakho (Paris Saint Germain).',
#  'Substitution, Lorient. Jeremie Aliadiere replaces KA©vin Monnet-Paquet.',
#  'Arnold Mvuemba (Lorient) hits the bar with a right footed shot from outside the box from a direct free kick.',
#  'Substitution, Paris Saint Germain. Jean Christophe Bahebeck replaces JA©rA©my Menez.',
#  'Julien Quercia (Lorient) wins a free kick on the left wing.',
#  'Foul by Christophe Jallet (Paris Saint Germain).',
#  'Attempt blocked. Blaise Matuidi (Paris Saint Germain) left footed shot from outside the box is blocked.',
#  'Corner,  Paris Saint Germain. Conceded by Bruno Ecuele Manga.',
#  'Attempt saved. Milan Bisevac (Paris Saint Germain) left footed shot from outside the box is saved in the bottom left corner.',
#  'Attempt missed. Kevin Gameiro (Paris Saint Germain) right footed shot from outside the box is high and wide to the right. Assisted by Jean Christophe Bahebeck.',
#  'Substitution, Lorient. Lynel Kitambala replaces Julien Quercia.',
#  'Offside, Lorient. Jeremie Aliadiere tries a through ball, but KA©vin Monnet-Paquet is caught offside.',
#  'Attempt saved. Arnold Mvuemba (Lorient) left footed shot from outside the box is saved in the bottom right corner. Assisted by Yann Jouffre.',
#  'Substitution, Lorient. Maxime Baca replaces Yann Jouffre.',
#  'Substitution, Paris Saint Germain. Mevlut Erding replaces Blaise Matuidi.',
#  'Corner,  Paris Saint Germain. Conceded by Jacques-Alaixys Romao.',
#  'Corner,  Paris Saint Germain. Conceded by GrA©gory Bourillon.',
#  'Foul by Jacques-Alaixys Romao (Lorient).',
#  'Mathieu Bodmer (Paris Saint Germain) wins a free kick on the left wing.',
#  'Attempt saved. NenAª (Paris Saint Germain) left footed shot from outside the box is saved in the top left corner. Assisted by Christophe Jallet.',
#  'Corner,  Paris Saint Germain. Conceded by Fabien Audard.',
#  'Offside, Paris Saint Germain. NenAª tries a through ball, but Mevlut Erding is caught offside.',
#  'Foul by Arnold Mvuemba (Lorient).',
#  'Mathieu Bodmer (Paris Saint Germain) wins a free kick in the defensive half.',
#  'Arnold Mvuemba (Lorient) is shown the yellow card for a bad foul.',
#  'Foul by Lynel Kitambala (Lorient).',
#  'ClA©ment Chantome (Paris Saint Germain) wins a free kick in the attacking half.',
#  'Lynel Kitambala (Lorient) is shown the yellow card for a bad foul.',
#  'Jeremie Aliadiere (Lorient) wins a free kick in the defensive half.',
#  'Foul by Siaka TiA©nA© (Paris Saint Germain).',
#  'Lynel Kitambala (Lorient) wins a free kick on the right wing.',
#  'Foul by NenAª (Paris Saint Germain).',
#  'Corner,  Lorient. Conceded by Christophe Jallet.',
#  'Attempt blocked. GrA©gory Pujol (Valenciennes) header from the right side of the six yard box is blocked. Assisted by Mathieu Dossevi with a cross.',
#  'Attempt missed. Romain Hamouma (Caen) left footed shot from outside the box misses to the right.',
#  'Renaud Cohade (Valenciennes) wins a free kick in the attacking half.',
#  'Foul by Gregory Proment (Caen).',
#  'Foul by Carlos SA¡nchez (Valenciennes).',
#  'Benjamin Nivet (Caen) wins a free kick in the attacking half.',
#  'Attempt missed. Jerry Van Dam (Caen) left footed shot from the right side of the box is too high. Assisted by Nicolas Seube.',
#  'GrA©gory Pujol (Valenciennes) wins a free kick in the attacking half.',
#  'Foul by Thomas Heurtaux (Caen).',
#  'Benjamin Nivet (Caen) wins a free kick in the attacking half.',
#  'Foul by Isimat Mirin (Valenciennes).',
#  'Foul by Carlos SA¡nchez (Valenciennes).',
#  'Gregory Proment (Caen) wins a free kick in the attacking half.',
#  'Carlos SA¡nchez (Valenciennes) is shown the yellow card for a bad foul.',
#  'Mathieu Dossevi (Valenciennes) wins a free kick on the right wing.',
#  'Foul by FrA©dA©ric Bulot (Caen).',
#  'Corner,  Valenciennes. Conceded by Alexandre Raineau.',
#  'Attempt missed. Benjamin Angoua (Valenciennes) header from very close range is too high. Assisted by Mathieu Dossevi with a cross following a corner.',
#  'Corner,  Valenciennes. Conceded by Jerry Van Dam.',
#  'Alexandre Raineau (Caen) wins a free kick in the defensive half.',
#  'Foul by Renaud Cohade (Valenciennes).',
#  'Attempt missed. Pierre-Alain Frau (Caen) left footed shot from outside the box is close, but misses the top left corner. Assisted by Gregory Leca.',
#  'Foul by Alexandre Raineau (Caen).',
#  'RA©mi Gomis (Valenciennes) wins a free kick on the right wing.',
#  'Corner,  Valenciennes. Conceded by Jerry Van Dam.',
#  'Offside, Caen. Romain Hamouma tries a through ball, but FrA©dA©ric Bulot is caught offside.',
#  'Foul by Alexandre Raineau (Caen).',
#  'RA©mi Gomis (Valenciennes) wins a free kick in the defensive half.',
#  'Corner,  Valenciennes. Conceded by Alexandre Raineau.',
#  'Attempt missed. Mathieu Dossevi (Valenciennes) header from a difficult angle on the left is close, but misses the top left corner. Assisted by GaA«l Danic with a cross.',
#  'Corner,  Caen. Conceded by Benjamin Angoua.',
#  'Attempt saved. GaA«l Danic (Valenciennes) left footed shot from outside the box is saved in the bottom right corner. Assisted by Mathieu Dossevi.',
#  'Attempt blocked. Gregory Proment (Caen) left footed shot from outside the box is blocked. Assisted by Benjamin Nivet.',
#  'Attempt missed. Pierre-Alain Frau (Caen) header from the centre of the box is close, but misses to the left. Assisted by FrA©dA©ric Bulot with a cross.',
#  'Goal!  Caen 1, Valenciennes 0. Gregory Proment (Caen) right footed shot from outside the box to the top right corner. Assisted by Nicolas Seube.',
#  'Offside, Valenciennes. GaA«l Danic tries a through ball, but GrA©gory Pujol is caught offside.',
#  'Attempt saved. GaA«l Danic (Valenciennes) header from the centre of the box is saved in the top left corner. Assisted by David Ducourtioux with a cross.',
#  'Corner,  Valenciennes. Conceded by Jerry Van Dam.',
#  'Attempt missed. Pierre-Alain Frau (Caen) right footed shot from outside the box is close, but misses to the left. Assisted by Romain Hamouma.',
#  'Pierre-Alain Frau (Caen) wins a free kick in the defensive half.',
#  'Foul by Isimat Mirin (Valenciennes).',
#  'Alexandre Raineau (Caen) wins a free kick on the left wing.',
#  'Foul by RA©mi Gomis (Valenciennes).',
#  'Hand ball by FrA©dA©ric Bulot (Caen).',
#  'Attempt saved. GaA«tan Bong (Valenciennes) left footed shot from outside the box is saved in the centre of the goal.',
#  'Attempt saved. GrA©gory Pujol (Valenciennes) right footed shot from the right side of the six yard box is saved in the bottom right corner.',
#  'Foul by Thomas Heurtaux (Caen).',
#  'Mathieu Dossevi (Valenciennes) wins a free kick in the attacking half.',
#  'Attempt missed. Mathieu Dossevi (Valenciennes) right footed shot from the centre of the box is too high following a set piece situation.',
#  'Attempt blocked. GrA©gory Pujol (Valenciennes) right footed shot from outside the box is blocked. Assisted by RA©mi Gomis.',
#  'Offside, Caen. Alexis ThA©baux tries a through ball, but Pierre-Alain Frau is caught offside.',
#  'Attempt saved. Romain Hamouma (Caen) left footed shot from outside the box is saved in the top centre of the goal.',
#  'Attempt saved. FrA©dA©ric Bulot (Caen) header from the centre of the box is saved in the centre of the goal. Assisted by Pierre-Alain Frau with a cross.',
#  'Corner,  Valenciennes. Conceded by Jerry Van Dam.',
#  'Corner,  Valenciennes. Conceded by Gregory Leca.',
#  'Corner,  Caen. Conceded by Isimat Mirin.',
#  'Corner,  Valenciennes. Conceded by Gregory Proment.',
#  'Jerry Van Dam (Caen) wins a free kick in the defensive half.',
#  'Foul by Benjamin Angoua (Valenciennes).',
#  'Attempt saved. GaA«l Danic (Valenciennes) left footed shot from the left side of the box is saved in the bottom right corner. Assisted by Mathieu Dossevi.',
#  'Substitution, Valenciennes. Foued Kadir replaces Mathieu Dossevi.',
#  'Hand ball by Nicolas Seube (Caen).',
#  'Substitution, Caen. Damien Marcq replaces Gregory Proment.',
#  'Foul by FrA©dA©ric Bulot (Caen).',
#  'Carlos SA¡nchez (Valenciennes) wins a free kick in the defensive half.',
#  'Pierre-Alain Frau (Caen) wins a free kick in the defensive half.',
#  'Foul by Isimat Mirin (Valenciennes).',
#  'Foul by Damien Marcq (Caen).',
#  'Benjamin Angoua (Valenciennes) wins a free kick in the attacking half.',
#  'Damien Marcq (Caen) is shown the yellow card for a bad foul.',
#  'Nicolas Seube (Caen) wins a free kick in the defensive half.',
#  'Foul by Carlos SA¡nchez (Valenciennes).',
#  'Substitution, Valenciennes. Mamadou Samassa replaces Renaud Cohade.',
#  'Substitution, Caen. JA©rA©my Sorbon replaces Jerry Van Dam.',
#  'JA©rA©my Sorbon (Caen) wins a free kick on the right wing.',
#  'Nicolas Seube (Caen) wins a free kick on the right wing.',
#  'Foul by GaA«l Danic (Valenciennes).',
#  'Foul by Gregory Leca (Caen).',
#  'Mamadou Samassa (Valenciennes) wins a free kick in the attacking half.',
#  'Attempt blocked. FrA©dA©ric Bulot (Caen) left footed shot from outside the box is blocked.',
#  'Corner,  Caen. Conceded by David Ducourtioux.',
#  'Corner,  Valenciennes. Conceded by Damien Marcq.',
#  'Attempt blocked. Foued Kadir (Valenciennes) left footed shot from the right side of the box is blocked.',
#  'Corner,  Valenciennes. Conceded by Alexandre Raineau.',
#  'Attempt saved. RA©mi Gomis (Valenciennes) header from the centre of the box is saved in the top centre of the goal. Assisted by Foued Kadir with a cross.',
#  'Corner,  Valenciennes. Conceded by Gregory Leca.',
#  'Attempt missed. Romain Hamouma (Caen) right footed shot from outside the box misses to the left. Assisted by Damien Marcq.',
#  'Foul by Pierre-Alain Frau (Caen).',
#  'GrA©gory Pujol (Valenciennes) wins a free kick in the defensive half.',
#  'Pierre-Alain Frau (Caen) is shown the yellow card for a bad foul.',
#  'Maik Franz (Hertha Berlin) wins a free kick in the defensive half.',
#  'Foul by Tunay Torun (Hertha Berlin).',
#  'Foul by Tomas Pekhart (FC Nurnberg).',
#  'Timothy Chandler (FC Nurnberg) wins a free kick in the defensive half.',
#  'Pierre-Michel Lasogga (Hertha Berlin) wins a free kick in the defensive half.',
#  'Foul by Timmy Simons (FC Nurnberg).',
#  'Foul by Andre Mijatovic (Hertha Berlin).',
#  'Tomas Pekhart (FC Nurnberg) wins a free kick on the right wing.',
#  'Hand ball by Tomas Pekhart (FC Nurnberg).',
#  'Corner,  FC Nurnberg. Conceded by Andre Mijatovic.',
#  'Attempt missed. Timm Klose (FC Nurnberg) right footed shot from the centre of the box is too high following a corner.',
#  'Levan Kobiashvili (Hertha Berlin) wins a free kick in the defensive half.',
#  'Patrick Ebert (Hertha Berlin) wins a free kick on the right wing.',
#  'Foul by Markus Mendler (FC Nurnberg).',
#  'Foul by Javier Pinola (FC Nurnberg).',
#  'Attempt missed. Andreas Ottl (Hertha Berlin) right footed shot from outside the box misses to the right following a set piece situation.',
#  'Attempt missed. Markus Mendler (FC Nurnberg) left footed shot from outside the box misses to the right.',
#  'Andreas Ottl (Hertha Berlin) wins a free kick in the defensive half.',
#  'Foul by Almog Cohen (FC Nurnberg).',
#  'Foul by Andreas Ottl (Hertha Berlin).',
#  'Peter Niemeyer (Hertha Berlin) wins a free kick in the defensive half.',
#  'Almog Cohen (FC Nurnberg) wins a free kick in the defensive half.',
#  'Foul by Markus Feulner (FC Nurnberg).',
#  'Offside, Hertha Berlin. Andreas Ottl tries a through ball, but Pierre-Michel Lasogga is caught offside.',
#  'Levan Kobiashvili (Hertha Berlin) wins a free kick in the defensive half.',
#  'Foul by Markus Feulner (FC Nurnberg).',
#  'Markus Feulner (FC Nurnberg) is shown the yellow card for a bad foul.',
#  'Andre Mijatovic (Hertha Berlin) wins a free kick in the defensive half.',
#  'Foul by Tomas Pekhart (FC Nurnberg).',
#  'Foul by Tunay Torun (Hertha Berlin).',
#  'Timothy Chandler (FC Nurnberg) wins a free kick on the right wing.',
#  'Attempt saved. Christian Eigler (FC Nurnberg) right footed shot from more than 35 yards is saved in the centre of the goal. Assisted by Javier Pinola with a headed pass.',
#  'Peter Niemeyer (Hertha Berlin) wins a free kick in the defensive half.',
#  'Foul by Philipp Wollscheid (FC Nurnberg).',
#  'Foul by Andre Mijatovic (Hertha Berlin).',
#  'Tomas Pekhart (FC Nurnberg) wins a free kick in the attacking half.',
#  'Attempt blocked. Markus Mendler (FC Nurnberg) left footed shot from the right side of the box is blocked. Assisted by Almog Cohen.',
#  'Levan Kobiashvili (Hertha Berlin) wins a free kick in the defensive half.',
#  'Foul by Tomas Pekhart (FC Nurnberg).',
#  'Corner,  FC Nurnberg. Conceded by Andre Mijatovic.',
#  'Corner,  FC Nurnberg. Conceded by Levan Kobiashvili.',
#  'Foul by Pierre-Michel Lasogga (Hertha Berlin).',
#  'Philipp Wollscheid (FC Nurnberg) wins a free kick in the defensive half.',
# ...
#  'Corner,  Brest. Conceded by Fabrice Ehret.',
#  'Attempt missed. Johan Martial (Brest) header from the centre of the box misses to the right. Assisted by Bruno Grougi with a cross following a corner.',
#  'Attempt saved. Nolan Roux (Brest) right footed shot from the left side of the box is saved in the centre of the goal. Assisted by Paul Baysse.',
#  'Corner,  Brest. Conceded by Quentin Westberg.',
#  'Corner,  Brest. Conceded by Brice Dja DjedjA©.',
#  'Corner,  Brest. Conceded by CA©dric Cambon.',
#  'Substitution, Brest. Mario Licka replaces Romain Poyet.',
#  'Corner,  Brest. Conceded by Mohammed Rabiu.',
#  'Corner,  Brest. Conceded by Fabrice Ehret.',
#  'Jerome Leroy (Evian Thonon Gaillard) wins a free kick in the attacking half.',
#  'Foul by Jhon Culma Jairo (Brest).',
#  'Jhon Culma Jairo (Brest) is shown the yellow card for a bad foul.',
#  'Attempt saved. Aldo Angoula (Evian Thonon Gaillard) right footed shot from the centre of the box is saved in the bottom left corner. Assisted by Mohammed Rabiu with a headed pass.',
#  'Substitution, Evian Thonon Gaillard. Guillaume Rippert replaces Ali Mmadi.',
#  'Offside, Evian Thonon Gaillard. Fabrice Ehret tries a through ball, but KA©vin Berigaud is caught offside.',
#  'Jerome Leroy (Evian Thonon Gaillard) wins a free kick on the left wing.',
#  'Corner,  Evian Thonon Gaillard. Conceded by Benoit Lesoimier.',
#  'Attempt missed. Jerome Leroy (Evian Thonon Gaillard) right footed shot from outside the box misses to the right following a corner.',
#  'Foul by Jhon Culma Jairo (Brest).',
#  'Aldo Angoula (Evian Thonon Gaillard) wins a free kick in the defensive half.',
#  'Foul by Eden Ben Basat (Brest).',
#  'Offside, Ajaccio. Yoann Poulard tries a through ball, but Richard Socrier is caught offside.',
#  'Fabrice Begeorgi (Ajaccio) wins a free kick on the left wing.',
#  'Foul by Daniel Congre (Toulouse).',
#  'Attempt saved. Frederic Sammaritano (Ajaccio) right footed shot from the centre of the box is saved in the centre of the goal. Assisted by Mehdi Mostefa with a cross.',
#  'Foul by Richard Socrier (Ajaccio).',
#  'Aymen Abdennour (Toulouse) wins a free kick in the defensive half.',
#  'Foul by Richard Socrier (Ajaccio).',
#  'Antoine Devaux (Toulouse) wins a free kick in the defensive half.',
#  'Fabrice Begeorgi (Ajaccio) wins a free kick in the defensive half.',
#  'Foul by MickaA«l Firmin (Toulouse).',
#  'Corner,  Toulouse. Conceded by Mehdi Mostefa.',
#  'Corner,  Toulouse. Conceded by Mehdi Mostefa.',
#  'Frederic Sammaritano (Ajaccio) wins a free kick in the defensive half.',
#  'Foul by Franck Tabanou (Toulouse).',
#  'Attempt blocked. Johan Cavalli (Ajaccio) left footed shot from outside the box is blocked. Assisted by Christian Kinkela.',
#  'Corner,  Ajaccio. Conceded by Mohamed Fofana.',
#  'Attempt missed. Mehdi Mostefa (Ajaccio) header from the right side of the six yard box is high and wide to the right. Assisted by Christian Kinkela with a cross following a corner.',
#  'Carl Medjani (Ajaccio) wins a free kick in the defensive half.',
#  'Foul by Umut Bulut (Toulouse).',
#  'Fabrice Begeorgi (Ajaccio) wins a free kick in the defensive half.',
#  'Foul by Moussa Sissoko (Toulouse).',
#  'Foul by Christian Kinkela (Ajaccio).',
#  'Daniel Congre (Toulouse) wins a free kick in the defensive half.',
#  'Benjamin Andre (Ajaccio) wins a free kick in the defensive half.',
#  'Foul by Moussa Sissoko (Toulouse).',
#  'Corner,  Toulouse. Conceded by Mehdi Mostefa.',
#  'Attempt saved. Antoine Devaux (Toulouse) header from the left side of the six yard box is saved in the top centre of the goal. Assisted by Paulo Machado with a cross.',
#  'Yoann Poulard (Ajaccio) wins a free kick in the defensive half.',
#  'Foul by Umut Bulut (Toulouse).',
#  'Fabrice Begeorgi (Ajaccio) wins a free kick on the left wing.',
#  'Foul by Paulo Machado (Toulouse).',
#  'Corner,  Ajaccio. Conceded by Cheikh Mbengue.',
#  'Attempt missed. Jean-Baptiste Pierazzi (Ajaccio) right footed shot from the centre of the box is too high following a corner.',
#  'Corner,  Ajaccio. Conceded by Aymen Abdennour.',
#  'Attempt missed. Yoann Poulard (Ajaccio) header from the centre of the box misses to the left. Assisted by Christian Kinkela with a cross following a corner.',
#  'Hand ball by Paulo Machado (Toulouse).',
#  'Corner,  Ajaccio. Conceded by Cheikh Mbengue.',
#  'Offside, Ajaccio. Fabrice Begeorgi tries a through ball, but Christian Kinkela is caught offside.',
#  'Foul by Johan Cavalli (Ajaccio).',
#  'Antoine Devaux (Toulouse) wins a free kick in the defensive half.',
#  'Daniel Congre (Toulouse) wins a free kick in the defensive half.',
#  'Johan Cavalli (Ajaccio) is shown the yellow card for a bad foul.',
#  'Attempt blocked. Jean-Baptiste Pierazzi (Ajaccio) right footed shot from outside the box is blocked.',
#  'Corner,  Ajaccio. Conceded by Antoine Devaux.',
#  'Attempt missed. Mehdi Mostefa (Ajaccio) header from the centre of the box is high and wide to the right. Assisted by Johan Cavalli with a cross following a corner.',
#  'Foul by Carl Medjani (Ajaccio).',
#  'Umut Bulut (Toulouse) wins a free kick in the attacking half.',
#  'Corner,  Ajaccio. Conceded by Cheikh Mbengue.',
#  'Attempt saved. Carl Medjani (Ajaccio) header from the centre of the box is saved in the centre of the goal. Assisted by Christian Kinkela with a cross.',
#  'Attempt blocked. Frederic Sammaritano (Ajaccio) right footed shot from outside the box is blocked.',
#  'Fabrice Begeorgi (Ajaccio) wins a free kick in the defensive half.',
#  'Foul by Moussa Sissoko (Toulouse).',
#  'Attempt saved. MickaA«l Firmin (Toulouse) right footed shot from outside the box is saved in the top left corner.',
#  'Attempt missed. Umut Bulut (Toulouse) right footed shot from the centre of the box is high and wide to the right. Assisted by Daniel Congre with a cross.',
#  'Foul by Richard Socrier (Ajaccio).',
#  'Franck Tabanou (Toulouse) wins a free kick in the defensive half.',
#  'Foul by Fabrice Begeorgi (Ajaccio).',
#  'Paulo Machado (Toulouse) wins a free kick on the right wing.',
#  'Goal!  Ajaccio 0, Toulouse 1. Antoine Devaux (Toulouse) header from the centre of the box to the bottom left corner. Assisted by Franck Tabanou with a cross following a set piece situation.',
#  'Attempt missed. Frederic Sammaritano (Ajaccio) left footed shot from the left side of the box is high and wide to the left. Assisted by Johan Cavalli.',
#  'Offside, Toulouse. Umut Bulut tries a through ball, but Franck Tabanou is caught offside.',
#  'Benjamin Andre (Ajaccio) wins a free kick on the right wing.',
#  'Foul by Cheikh Mbengue (Toulouse).',
#  'Corner,  Ajaccio. Conceded by Antoine Devaux.',
#  'Corner,  Ajaccio. Conceded by Paulo Machado.',
#  'Christian Kinkela (Ajaccio) wins a free kick on the right wing.',
#  'Foul by Moussa Sissoko (Toulouse).',
#  'Moussa Sissoko (Toulouse) is shown the yellow card for a bad foul.',
#  'Corner,  Ajaccio. Conceded by Mohamed Fofana.',
#  'Attempt missed. Paulo Machado (Toulouse) right footed shot from outside the box is close, but misses to the right. Assisted by Franck Tabanou following a fast break.',
#  'Foul by Jean-Baptiste Pierazzi (Ajaccio).',
#  'Antoine Devaux (Toulouse) wins a free kick in the defensive half.',
#  'Attempt saved. Franck Tabanou (Toulouse) left footed shot from outside the box is saved in the top left corner.',
#  'Corner,  Toulouse. Conceded by Yoann Poulard.',
#  'Attempt blocked. Umut Bulut (Toulouse) left footed shot from the centre of the box is blocked.',
#  'Attempt saved. Paulo Machado (Toulouse) with an attempt from a difficult angle and long range on the left is saved in the bottom left corner. Assisted by Franck Tabanou.',
#  'Foul by Benjamin Andre (Ajaccio).',
#  'Foul by Jean-Baptiste Pierazzi (Ajaccio).',
#  'MickaA«l Firmin (Toulouse) wins a free kick in the defensive half.',
#  'Frederic Sammaritano (Ajaccio) wins a free kick on the left wing.',
#  'Foul by Daniel Congre (Toulouse).',
#  'Attempt missed. Moussa Sissoko (Toulouse) right footed shot from outside the box is high and wide to the right. Assisted by Cheikh Mbengue with a cross.',
#  'Substitution, Ajaccio. Ilan replaces Richard Socrier.',
#  'Substitution, Ajaccio. Damien TibA©ri replaces Christian Kinkela.',
#  'Attempt missed. Frederic Sammaritano (Ajaccio) left footed shot from the centre of the box is close, but misses the top left corner. Assisted by Benjamin Andre with a cross.',
#  'Attempt missed. Damien TibA©ri (Ajaccio) left footed shot from the left side of the box is just a bit too high. Assisted by Fabrice Begeorgi.',
#  'Benjamin Andre (Ajaccio) wins a free kick in the defensive half.',
#  'Foul by MickaA«l Firmin (Toulouse).',
#  'Corner,  Ajaccio. Conceded by Paulo Machado.',
#  'Attempt blocked. Yoann Poulard (Ajaccio) left footed shot from the centre of the box is blocked. Assisted by Frederic Sammaritano with a cross.',
#  'Attempt blocked. Carl Medjani (Ajaccio) right footed shot from the left side of the box is blocked.',
#  'Attempt saved. Jean-Baptiste Pierazzi (Ajaccio) right footed shot from outside the box is saved in the centre of the goal. Assisted by Johan Cavalli with a headed pass.',
#  'Attempt missed. Franck Tabanou (Toulouse) left footed shot from outside the box misses to the right. Assisted by Aymen Abdennour.',
#  'Substitution, Toulouse. Pantxi Sirieix replaces MickaA«l Firmin.',
#  'Goal!  Ajaccio 0, Toulouse 2. Paulo Machado (Toulouse) right footed shot from outside the box to the top right corner. Assisted by Cheikh Mbengue.',
#  'Substitution, Toulouse. Jean Daniel Akpa Akpro replaces Cheikh Mbengue.',
#  'Substitution, Ajaccio. Andy Delort replaces Johan Cavalli.',
#  'Attempt saved. Jean Daniel Akpa Akpro (Toulouse) right footed shot from outside the box is saved in the top right corner. Assisted by Moussa Sissoko.',
#  'Foul by Damien TibA©ri (Ajaccio).',
#  'Daniel Congre (Toulouse) wins a free kick on the right wing.',
#  'Damien TibA©ri (Ajaccio) is shown the yellow card for a bad foul.',
#  'Attempt saved. Frederic Sammaritano (Ajaccio) left footed shot from the right side of the box is saved in the centre of the goal. Assisted by Ilan.',
#  'Andy Delort (Ajaccio) wins a free kick on the left wing.',
#  'Foul by Mohamed Fofana (Toulouse).',
#  'Mohamed Fofana (Toulouse) is shown the yellow card for a bad foul.',
#  'Benjamin Andre (Ajaccio) is shown the yellow card.',
#  'Substitution, Toulouse. Xavier Pentecote replaces Umut Bulut.',
#  'Foul by Andy Delort (Ajaccio).',
#  'Mohamed Fofana (Toulouse) wins a free kick in the defensive half.',
#  'Andy Delort (Ajaccio) is shown the yellow card for a bad foul.',
#  'Benjamin Andre (Ajaccio) wins a free kick on the right wing.',
#  'Foul by Moussa Sissoko (Toulouse).',
#  'Attempt saved. Xavier Pentecote (Toulouse) right footed shot from the centre of the box is saved in the bottom left corner. Assisted by Moussa Sissoko.',
#  'Attempt saved. Damien TibA©ri (Ajaccio) left footed shot from outside the box is saved in the centre of the goal. Assisted by Frederic Sammaritano.',
#  'Fabrice Begeorgi (Ajaccio) wins a free kick in the attacking half.',
#  'Foul by Antoine Devaux (Toulouse).',
#  'Attempt saved. Andy Delort (Ajaccio) right footed shot from outside the box is saved in the bottom left corner.',
#  'Corner,  Ajaccio. Conceded by Ali Ahamada.',
#  'Corner,  Nice. Conceded by Aly Cissokho.',
#  'Attempt saved. David Hellebuyck (Nice) left footed shot from outside the box is saved in the top centre of the goal. Assisted by Luciano FabiA¡n MonzA³n.',
#  'Corner,  Nice. Conceded by Hugo Lloris.',
#  'Attempt missed. Francois Clerc (Nice) right footed shot from outside the box is high and wide to the left following a corner.',
#  'Corner,  Nice. Conceded by Anthony RA©veillere.',
#  'Goal!  Nice 1, Lyon 0. Anthony Mounier (Nice) header from the centre of the box to the top right corner. Assisted by Camel Meriem with a cross following a corner.',
#  'Foul by Cris (Lyon).',
#  'Eric Mouloungui (Nice) wins a free kick on the left wing.',
#  'Offside, Nice. Luciano FabiA¡n MonzA³n tries a through ball, but Eric Mouloungui is caught offside.',
#  'Foul by Michel Bastos (Lyon).',
#  'Julien SablA© (Nice) wins a free kick in the attacking half.',
#  'Goal!  Nice 1, Lyon 1. Lisandro (Lyon) right footed shot from the centre of the box to the bottom right corner. Assisted by Anthony RA©veillere following a fast break.',
#  'Foul by Maxime Gonalons (Lyon).',
#  'Didier Digard (Nice) wins a free kick in the attacking half.',
#  'Corner,  Nice. Conceded by Cris.',
#  'Corner,  Nice. Conceded by Dejan Lovren.',
#  'Attempt blocked. David Hellebuyck (Nice) left footed shot from the left side of the box is blocked. Assisted by Camel Meriem with a cross.',
#  'Corner,  Nice. Conceded by Michel Bastos.',
#  'Attempt missed. Julien SablA© (Nice) right footed shot from outside the box misses to the right following a corner.',
#  'Attempt missed. Jimmy Briand (Lyon) left footed shot from outside the box is close, but misses the top left corner. Assisted by BafA©timbi Gomis.',
#  'Foul by Cris (Lyon).',
#  'Eric Mouloungui (Nice) wins a free kick in the attacking half.',
#  'Attempt blocked. Luciano FabiA¡n MonzA³n (Nice) left footed shot from more than 35 yards is blocked.',
#  'Attempt saved. Lisandro (Lyon) right footed shot from the centre of the box is saved in the bottom right corner.',
#  'Corner,  Nice. Conceded by Dejan Lovren.',
#  'BafA©timbi Gomis (Lyon) wins a free kick in the defensive half.',
#  'Foul by David Hellebuyck (Nice).',
#  'Offside, Nice. Luciano FabiA¡n MonzA³n tries a through ball, but Eric Mouloungui is caught offside.',
#  'Foul by Dejan Lovren (Lyon).',
#  'Eric Mouloungui (Nice) wins a free kick in the defensive half.',
#  'Corner,  Nice. Conceded by Cris.',
#  'Attempt saved. Larrys Mabiala (Nice) header from the centre of the box is saved in the top right corner. Assisted by Camel Meriem with a cross.',
#  'Lisandro (Lyon) wins a free kick in the defensive half.',
#  'Foul by Larrys Mabiala (Nice).',
#  'Corner,  Lyon. Conceded by Luciano FabiA¡n MonzA³n.',
#  'Attempt blocked. Michel Bastos (Lyon) left footed shot from a difficult angle and long range on the right is blocked. Assisted by Jimmy Briand.',
#  'Corner,  Lyon. Conceded by Larrys Mabiala.',
#  'Foul by Aly Cissokho (Lyon).',
#  'Eric Mouloungui (Nice) wins a free kick in the attacking half.',
#  'Attempt missed. Anthony Mounier (Nice) left footed shot from outside the box is high and wide to the right from a direct free kick.',
#  'BafA©timbi Gomis (Lyon) wins a free kick in the attacking half.',
#  'Foul by Anthony Mounier (Nice).',
#  'Attempt blocked. Michel Bastos (Lyon) left footed shot from more than 35 yards is blocked.',
#  'Attempt saved. Aly Cissokho (Lyon) left footed shot from outside the box is saved in the bottom left corner. Assisted by Kim KA¤llstrA¶m.',
#  'Michel Bastos (Lyon) wins a free kick in the attacking half.',
#  'Foul by Didier Digard (Nice).',
#  'Attempt saved. Kim KA¤llstrA¶m (Lyon) left footed shot from outside the box is saved in the bottom left corner.',
#  'Corner,  Lyon. Conceded by David Ospina.',
#  'Attempt missed. BafA©timbi Gomis (Lyon) header from very close range misses to the left following a corner.',
#  'Goal!  Nice 1, Lyon 2. BafA©timbi Gomis (Lyon) right footed shot from very close range to the top right corner following a corner.',
#  'Attempt missed. Kim KA¤llstrA¶m (Lyon) left footed shot from outside the box misses to the right. Assisted by Maxime Gonalons.',
#  'Attempt blocked. Michel Bastos (Lyon) left footed shot from the left side of the box is blocked. Assisted by Kim KA¤llstrA¶m.',
#  'Corner,  Lyon. Conceded by Larrys Mabiala.',
#  'Attempt blocked. Jimmy Briand (Lyon) header from the centre of the box is blocked. Assisted by Michel Bastos with a cross.',
#  'Offside, Nice. Didier Digard tries a through ball, but Eric Mouloungui is caught offside.',
#  'Corner,  Lyon. Conceded by Nemanja Pejcinovic.',
#  'Eric Mouloungui (Nice) wins a free kick in the attacking half.',
#  'Foul by Cris (Lyon).',
#  'Attempt missed. Eric Mouloungui (Nice) right footed shot from the right side of the box misses to the right. Assisted by Didier Digard.',
#  ...]
